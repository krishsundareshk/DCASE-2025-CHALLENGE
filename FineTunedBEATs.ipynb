# %% [markdown]
# Fine Tuned Model using BEATs

# %%
import os
import sys
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from transformers import Trainer, TrainingArguments, set_seed
from peft import get_peft_model, LoraConfig

# Add the BEATs repo to the Python path so that the import works
sys.path.append("K:/DCASE/BEATs")
from BEATs import BEATs, BEATsConfig

# ===== CONFIGURATION =====
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
CHECKPOINT_PATH = "K:/DCASE/BEATs_iter3.pt"  # frozen BEATs_iter3 checkpoint
TRAIN_DIR = "K:/DCASE/Trainingdata/Source"            # Contains 7 machine folders, 1000 .wav files each
OUTPUT_MODEL_PATH = "K:/DCASE/BEATs_finetuned_1.pt"
SEED = 42

# Hyperparameters
BATCH_SIZE = 2                 # Reduced batch size
NUM_EPOCHS = 5
LEARNING_RATE = 5e-5
TARGET_SECONDS = 15            # Shorter duration to reduce memory (15 sec instead of 30)
TARGET_LEN = 16000 * TARGET_SECONDS  # Total samples (240,000)

set_seed(SEED)

# ===== Load BEATs Model =====
print("🔄 Loading BEATs checkpoint...")
checkpoint = torch.load(CHECKPOINT_PATH, map_location=DEVICE)
cfg = BEATsConfig()
cfg.input_patch_size = (16, 16)
cfg.conv_bias = checkpoint["cfg"].get("conv_bias", False)
cfg.frame_length = 384  # Use 384 for the frame_length requirement
model = BEATs(cfg)
model.load_state_dict(checkpoint["model"], strict=False)
model.to(DEVICE)
model.eval()
print("✅ BEATs model loaded successfully!")

# ===== Apply QLoRA =====
print("⚙️ Applying QLoRA...")
peft_config = LoraConfig(
    r=8,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="FEATURE_EXTRACTION",
    target_modules=["q_proj", "v_proj"]  # Target attention projection layers
)
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# ===== Custom Dataset =====
class AudioDataset(Dataset):
    def __init__(self, base_dir):
        self.file_list = []
        for machine in os.listdir(base_dir):
            machine_path = os.path.join(base_dir, machine)
            if not os.path.isdir(machine_path):
                continue
            for fname in os.listdir(machine_path):
                if fname.lower().endswith(".wav"):
                    self.file_list.append(os.path.join(machine_path, fname))
        print(f"Found {len(self.file_list)} audio files.")

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        wav_path = self.file_list[idx]
        try:
            waveform, sr = torchaudio.load(wav_path)
        except Exception as e:
            print(f"Error loading {wav_path}: {e}")
            waveform = torch.zeros(1, TARGET_LEN)
            sr = 16000

        if waveform.shape[0] > 1:
            waveform = waveform.mean(dim=0, keepdim=True)
        if sr != 16000:
            resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
            waveform = resampler(waveform)
        if waveform.shape[1] < TARGET_LEN:
            waveform = torch.nn.functional.pad(waveform, (0, TARGET_LEN - waveform.shape[1]))
        else:
            waveform = waveform[:, :TARGET_LEN]
        return {"input_values": waveform.squeeze(0)}  # Returns a 1D tensor of length TARGET_LEN

# ===== Data Collator =====
def collate_fn(batch):
    processed = []
    for item in batch:
        if not isinstance(item, dict) or "input_values" not in item:
            processed.append(torch.zeros(TARGET_LEN))
        else:
            processed.append(item["input_values"])
    inputs = torch.stack(processed)
    return {"input_values": inputs}

# ===== Prepare DataLoader =====
train_dataset = AudioDataset(TRAIN_DIR)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)
# ===== Custom Trainer =====
class BEATsTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        # inputs["input_values"] has shape: [B, T]
        waveforms = inputs["input_values"].to(DEVICE)  # [B, T]
        # Pass waveforms directly; let model.extract_features handle channel addition
        features = model.extract_features(waveforms)[0]
        loss = torch.mean(features ** 2)
        return (loss, features) if return_outputs else loss

training_args = TrainingArguments(
    output_dir="./beats-qlora-checkpoints",
    per_device_train_batch_size=BATCH_SIZE,
    num_train_epochs=NUM_EPOCHS,
    learning_rate=LEARNING_RATE,
    logging_steps=50,
    save_strategy="no",
    report_to="none",
    fp16=True,                      # Enable mixed precision
    gradient_accumulation_steps=4,  # Accumulate gradients for effective batch size
)

trainer = BEATsTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    data_collator=collate_fn
)

# ===== Fine-Tuning Loop =====
print("🚀 Starting QLoRA fine-tuning...")
trainer.train()
print("✅ Fine-tuning completed!")

# ===== Save the Fine-Tuned Model =====
print(f"💾 Saving fine-tuned model to {OUTPUT_MODEL_PATH}")
torch.save({
    "cfg": checkpoint["cfg"],
    "model": model.state_dict()
}, OUTPUT_MODEL_PATH)
print("✅ Fine-tuned model saved!")
# Out:
# 🔄 Loading BEATs checkpoint...
# No label_names provided for model class `PeftModelForFeatureExtraction`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# ✅ BEATs model loaded successfully!
# ⚙️ Applying QLoRA...
# trainable params: 294,912 || all params: 90,596,480 || trainable%: 0.3255
# Found 6930 audio files.
# 🚀 Starting QLoRA fine-tuning...
#     <div>
#
#       <progress value='9' max='4330' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [   9/4330 00:05 < 57:04, 1.26 it/s, Epoch 0.01/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 137
#     135 # ===== Fine-Tuning Loop =====
#     136 print("🚀 Starting QLoRA fine-tuning...")
# --> 137 trainer.train()
#     138 print("✅ Fine-tuning completed!")
#     140 # ===== Save the Fine-Tuned Model =====
#
# File c:\Users\krishkannan\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\trainer.py:2245, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2243         hf_hub_utils.enable_progress_bars()
#    2244 else:
# -> 2245     return inner_training_loop(
#    2246         args=args,
#    2247         resume_from_checkpoint=resume_from_checkpoint,
#    2248         trial=trial,
#    2249         ignore_keys_for_eval=ignore_keys_for_eval,
#    2250     )
#
# File c:\Users\krishkannan\AppData\Local\Programs\Python\Python313\Lib\site-packages\transformers\trainer.py:2561, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2555 with context():
#    2556     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2558 if (
#    2559     args.logging_nan_inf_filter
#    2560     and not is_torch_xla_available()
# -> 2561     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2562 ):
#    2563     # if loss is nan or inf simply add the average of previous logged losses
#    2564     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#    2565 else:
#
# KeyboardInterrupt:

# %%
import os
import sys
import torch
import torchaudio
from torch.utils.data import Dataset, DataLoader
from tqdm import tqdm
from transformers import Trainer, TrainingArguments, set_seed
from peft import get_peft_model, LoraConfig

# Add the BEATs repo to the Python path so that the import works
sys.path.append("K:/DCASE/BEATs")
from BEATs import BEATs, BEATsConfig

# ===== CONFIGURATION =====
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
CHECKPOINT_PATH = "K:/DCASE/BEATs_iter3.pt"  # frozen BEATs_iter3 checkpoint
TRAIN_DIR = "K:/DCASE/Trainingdata/Source"            # Contains 7 machine folders, 1000 .wav files each
OUTPUT_MODEL_PATH = "K:/DCASE/BEATs_finetuned_1.pt"
SEED = 42

# Hyperparameters
BATCH_SIZE = 2                 # Reduced batch size
NUM_EPOCHS = 12
LEARNING_RATE = 5e-5
TARGET_SECONDS = 15            # Shorter duration to reduce memory (15 sec instead of 30)
TARGET_LEN = 16000 * TARGET_SECONDS  # Total samples (240,000)

set_seed(SEED)

# ===== Load BEATs Model =====
print("🔄 Loading BEATs checkpoint...")
checkpoint = torch.load(CHECKPOINT_PATH, map_location=DEVICE)
cfg = BEATsConfig()
cfg.input_patch_size = (16, 16)
cfg.conv_bias = checkpoint["cfg"].get("conv_bias", False)
cfg.frame_length = 384  # Use 384 for the frame_length requirement
model = BEATs(cfg)
model.load_state_dict(checkpoint["model"], strict=False)
model.to(DEVICE)
model.eval()
print("✅ BEATs model loaded successfully!")

# ===== Apply QLoRA =====
print("⚙️ Applying QLoRA...")
peft_config = LoraConfig(
    r=8,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="FEATURE_EXTRACTION",
    target_modules=["q_proj", "v_proj"]  # Target attention projection layers
)
model = get_peft_model(model, peft_config)
model.print_trainable_parameters()

# ===== Custom Dataset =====
class AudioDataset(Dataset):
    def __init__(self, base_dir):
        self.file_list = []
        for machine in os.listdir(base_dir):
            machine_path = os.path.join(base_dir, machine)
            if not os.path.isdir(machine_path):
                continue
            for fname in os.listdir(machine_path):
                if fname.lower().endswith(".wav"):
                    self.file_list.append(os.path.join(machine_path, fname))
        print(f"Found {len(self.file_list)} audio files.")

    def __len__(self):
        return len(self.file_list)

    def __getitem__(self, idx):
        wav_path = self.file_list[idx]
        try:
            waveform, sr = torchaudio.load(wav_path)
        except Exception as e:
            print(f"Error loading {wav_path}: {e}")
            waveform = torch.zeros(1, TARGET_LEN)
            sr = 16000

        if waveform.shape[0] > 1:
            waveform = waveform.mean(dim=0, keepdim=True)
        if sr != 16000:
            resampler = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)
            waveform = resampler(waveform)
        if waveform.shape[1] < TARGET_LEN:
            waveform = torch.nn.functional.pad(waveform, (0, TARGET_LEN - waveform.shape[1]))
        else:
            waveform = waveform[:, :TARGET_LEN]
        return {"input_values": waveform.squeeze(0)}  # Returns a 1D tensor of length TARGET_LEN

# ===== Data Collator =====
def collate_fn(batch):
    processed = []
    for item in batch:
        if not isinstance(item, dict) or "input_values" not in item:
            processed.append(torch.zeros(TARGET_LEN))
        else:
            processed.append(item["input_values"])
    inputs = torch.stack(processed)
    return {"input_values": inputs}

# ===== Prepare DataLoader =====
train_dataset = AudioDataset(TRAIN_DIR)
train_loader = DataLoader(train_dataset, batch_size=BATCH_SIZE, shuffle=True, collate_fn=collate_fn)
# ===== Custom Trainer =====
class BEATsTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        # inputs["input_values"] has shape: [B, T]
        waveforms = inputs["input_values"].to(DEVICE)  # [B, T]
        # Pass waveforms directly; let model.extract_features handle channel addition
        features = model.extract_features(waveforms)[0]
        loss = torch.mean(features ** 2)
        return (loss, features) if return_outputs else loss

training_args = TrainingArguments(
    output_dir="./beats-qlora-checkpoints",
    per_device_train_batch_size=BATCH_SIZE,
    num_train_epochs=NUM_EPOCHS,
    learning_rate=LEARNING_RATE,
    logging_steps=50,
    save_strategy="no",
    report_to="none",
    fp16=True,                      # Enable mixed precision
    gradient_accumulation_steps=4,  # Accumulate gradients for effective batch size
)

trainer = BEATsTrainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    data_collator=collate_fn
)

# ===== Fine-Tuning Loop =====
print("🚀 Starting QLoRA fine-tuning...")
trainer.train()
print("✅ Fine-tuning completed!")

# ===== Save the Fine-Tuned Model =====
print(f"💾 Saving fine-tuned model to {OUTPUT_MODEL_PATH}")
torch.save({
    "cfg": checkpoint["cfg"],
    "model": model.state_dict()
}, OUTPUT_MODEL_PATH)
print("✅ Fine-tuned model saved!")
# Out:
# 🔄 Loading BEATs checkpoint...
# No label_names provided for model class `PeftModelForFeatureExtraction`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# ✅ BEATs model loaded successfully!
# ⚙️ Applying QLoRA...
# trainable params: 294,912 || all params: 90,596,480 || trainable%: 0.3255
# Found 6930 audio files.
# 🚀 Starting QLoRA fine-tuning...
#     <div>
#
#       <progress value='10392' max='10392' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [10392/10392 2:33:13, Epoch 11/12]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>50</td>
#       <td>0.126200</td>
#     </tr>
#     <tr>
#       <td>100</td>
#       <td>0.094400</td>
#     </tr>
#     <tr>
#       <td>150</td>
#       <td>0.059100</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>0.043300</td>
#     </tr>
#     <tr>
#       <td>250</td>
#       <td>0.037700</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>0.034600</td>
#     </tr>
#     <tr>
#       <td>350</td>
#       <td>0.032600</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>0.031100</td>
#     </tr>
#     <tr>
#       <td>450</td>
#       <td>0.030000</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>0.029100</td>
#     </tr>
#     <tr>
#       <td>550</td>
#       <td>0.028300</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>0.027600</td>
#     </tr>
#     <tr>
#       <td>650</td>
#       <td>0.027000</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0.026400</td>
#     </tr>
#     <tr>
#       <td>750</td>
#       <td>0.025800</td>
#     </tr>
#     <tr>
#       <td>800</td>
#       <td>0.025400</td>
#     </tr>
#     <tr>
#       <td>850</td>
#       <td>0.024900</td>
#     </tr>
#     <tr>
#       <td>900</td>
#       <td>0.024100</td>
#     </tr>
#     <tr>
#       <td>950</td>
#       <td>0.024000</td>
#     </tr>
#     <tr>
#       <td>1000</td>
#       <td>0.023600</td>
#     </tr>
#     <tr>
#       <td>1050</td>
#       <td>0.023200</td>
#     </tr>
#     <tr>
#       <td>1100</td>
#       <td>0.023000</td>
#     </tr>
#     <tr>
#       <td>1150</td>
#       <td>0.022700</td>
#     </tr>
#     <tr>
#       <td>1200</td>
#       <td>0.022500</td>
#     </tr>
#     <tr>
#       <td>1250</td>
#       <td>0.022300</td>
#     </tr>
#     <tr>
#       <td>1300</td>
#       <td>0.022000</td>
#     </tr>
#     <tr>
#       <td>1350</td>
#       <td>0.021900</td>
#     </tr>
#     <tr>
#       <td>1400</td>
#       <td>0.021700</td>
#     </tr>
#     <tr>
#       <td>1450</td>
#       <td>0.021500</td>
#     </tr>
#     <tr>
#       <td>1500</td>
#       <td>0.021300</td>
#     </tr>
#     <tr>
#       <td>1550</td>
#       <td>0.021200</td>
#     </tr>
#     <tr>
#       <td>1600</td>
#       <td>0.021100</td>
#     </tr>
#     <tr>
#       <td>1650</td>
#       <td>0.020900</td>
#     </tr>
#     <tr>
#       <td>1700</td>
#       <td>0.020800</td>
#     </tr>
#     <tr>
#       <td>1750</td>
#       <td>0.020400</td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.020600</td>
#     </tr>
#     <tr>
#       <td>1850</td>
#       <td>0.020400</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.020300</td>
#     </tr>
#     <tr>
#       <td>1950</td>
#       <td>0.020200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.020100</td>
#     </tr>
#     <tr>
#       <td>2050</td>
#       <td>0.020100</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.020000</td>
#     </tr>
#     <tr>
#       <td>2150</td>
#       <td>0.019900</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.019800</td>
#     </tr>
#     <tr>
#       <td>2250</td>
#       <td>0.019700</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.019600</td>
#     </tr>
#     <tr>
#       <td>2350</td>
#       <td>0.019500</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.019400</td>
#     </tr>
#     <tr>
#       <td>2450</td>
#       <td>0.019300</td>
#     </tr>
#     <tr>
#       <td>2500</td>
#       <td>0.019300</td>
#     </tr>
#     <tr>
#       <td>2550</td>
#       <td>0.019200</td>
#     </tr>
#     <tr>
#       <td>2600</td>
#       <td>0.019100</td>
#     </tr>
#     <tr>
#       <td>2650</td>
#       <td>0.018700</td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.018900</td>
#     </tr>
#     <tr>
#       <td>2750</td>
#       <td>0.018800</td>
#     </tr>
#     <tr>
#       <td>2800</td>
#       <td>0.018700</td>
#     </tr>
#     <tr>
#       <td>2850</td>
#       <td>0.018600</td>
#     </tr>
#     <tr>
#       <td>2900</td>
#       <td>0.018500</td>
#     </tr>
#     <tr>
#       <td>2950</td>
#       <td>0.018400</td>
#     </tr>
#     <tr>
#       <td>3000</td>
#       <td>0.018400</td>
#     </tr>
#     <tr>
#       <td>3050</td>
#       <td>0.018300</td>
#     </tr>
#     <tr>
#       <td>3100</td>
#       <td>0.018200</td>
#     </tr>
#     <tr>
#       <td>3150</td>
#       <td>0.018100</td>
#     </tr>
#     <tr>
#       <td>3200</td>
#       <td>0.018100</td>
#     </tr>
#     <tr>
#       <td>3250</td>
#       <td>0.018000</td>
#     </tr>
#     <tr>
#       <td>3300</td>
#       <td>0.017900</td>
#     </tr>
#     <tr>
#       <td>3350</td>
#       <td>0.017900</td>
#     </tr>
#     <tr>
#       <td>3400</td>
#       <td>0.017800</td>
#     </tr>
#     <tr>
#       <td>3450</td>
#       <td>0.017800</td>
#     </tr>
#     <tr>
#       <td>3500</td>
#       <td>0.017400</td>
#     </tr>
#     <tr>
#       <td>3550</td>
#       <td>0.017600</td>
#     </tr>
#     <tr>
#       <td>3600</td>
#       <td>0.017600</td>
#     </tr>
#     <tr>
#       <td>3650</td>
#       <td>0.017600</td>
#     </tr>
#     <tr>
#       <td>3700</td>
#       <td>0.017500</td>
#     </tr>
#     <tr>
#       <td>3750</td>
#       <td>0.017500</td>
#     </tr>
#     <tr>
#       <td>3800</td>
#       <td>0.017400</td>
#     </tr>
#     <tr>
#       <td>3850</td>
#       <td>0.017400</td>
#     </tr>
#     <tr>
#       <td>3900</td>
#       <td>0.017400</td>
#     </tr>
#     <tr>
#       <td>3950</td>
#       <td>0.017300</td>
#     </tr>
#     <tr>
#       <td>4000</td>
#       <td>0.017300</td>
#     </tr>
#     <tr>
#       <td>4050</td>
#       <td>0.017200</td>
#     </tr>
#     <tr>
#       <td>4100</td>
#       <td>0.017200</td>
#     </tr>
#     <tr>
#       <td>4150</td>
#       <td>0.017200</td>
#     </tr>
#     <tr>
#       <td>4200</td>
#       <td>0.017100</td>
#     </tr>
#     <tr>
#       <td>4250</td>
#       <td>0.017100</td>
#     </tr>
#     <tr>
#       <td>4300</td>
#       <td>0.017100</td>
#     </tr>
#     <tr>
#       <td>4350</td>
#       <td>0.016800</td>
#     </tr>
#     <tr>
#       <td>4400</td>
#       <td>0.017000</td>
#     </tr>
#     <tr>
#       <td>4450</td>
#       <td>0.017000</td>
#     </tr>
#     <tr>
#       <td>4500</td>
#       <td>0.017000</td>
#     </tr>
#     <tr>
#       <td>4550</td>
#       <td>0.016900</td>
#     </tr>
#     <tr>
#       <td>4600</td>
#       <td>0.016900</td>
#     </tr>
#     <tr>
#       <td>4650</td>
#       <td>0.016900</td>
#     </tr>
#     <tr>
#       <td>4700</td>
#       <td>0.016900</td>
#     </tr>
#     <tr>
#       <td>4750</td>
#       <td>0.016900</td>
#     </tr>
#     <tr>
#       <td>4800</td>
#       <td>0.016800</td>
#     </tr>
#     <tr>
#       <td>4850</td>
#       <td>0.016800</td>
#     </tr>
#     <tr>
#       <td>4900</td>
#       <td>0.016800</td>
#     </tr>
#     <tr>
#       <td>4950</td>
#       <td>0.016800</td>
#     </tr>
#     <tr>
#       <td>5000</td>
#       <td>0.016800</td>
#     </tr>
#     <tr>
#       <td>5050</td>
#       <td>0.016700</td>
#     </tr>
#     <tr>
#       <td>5100</td>
#       <td>0.016700</td>
#     </tr>
#     <tr>
#       <td>5150</td>
#       <td>0.016700</td>
#     </tr>
#     <tr>
#       <td>5200</td>
#       <td>0.016700</td>
#     </tr>
#     <tr>
#       <td>5250</td>
#       <td>0.016400</td>
#     </tr>
#     <tr>
#       <td>5300</td>
#       <td>0.016700</td>
#     </tr>
#     <tr>
#       <td>5350</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>5400</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>5450</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>5500</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>5550</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>5600</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>5650</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>5700</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>5750</td>
#       <td>0.016600</td>
#     </tr>
#     <tr>
#       <td>5800</td>
#       <td>0.016500</td>
#     </tr>
#     <tr>
#       <td>5850</td>
#       <td>0.016500</td>
#     </tr>
#     <tr>
#       <td>5900</td>
#       <td>0.016500</td>
#     </tr>
#     <tr>
#       <td>5950</td>
#       <td>0.016500</td>
#     </tr>
#     <tr>
#       <td>6000</td>
#       <td>0.016500</td>
#     </tr>
#     <tr>
#       <td>6050</td>
#       <td>0.016500</td>
#     </tr>
#     <tr>
#       <td>6100</td>
#       <td>0.016200</td>
# ✅ Fine-tuning completed!
# 💾 Saving fine-tuned model to K:/DCASE/BEATs_finetuned_1.pt
# ✅ Fine-tuned model saved!

# %%
import torch
device = "cuda" if torch.cuda.is_available()  else "cpu"
# Out:
# cuda

# %%
import os, sys, torch, torchaudio
from torch.utils.data import Dataset
from transformers import Trainer, TrainingArguments, set_seed
from peft import get_peft_model, LoraConfig
from tqdm import tqdm

# ===== Paths =====
sys.path.append("K:/DCASE/BEATs")
from BEATs import BEATs, BEATsConfig

# ===== Config =====
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
SOURCE_MODEL_PATH = "K:/DCASE/BEATs_finetuned_1.pt"
TARGET_DIR = "K:/DCASE/Trainingdata/Target"
OUTPUT_MODEL_PATH = "K:/DCASE/BEATs_finetuned_target.pt"
SEED = 42
BATCH_SIZE = 2
NUM_EPOCHS = 5
LEARNING_RATE = 3e-5
TARGET_SECONDS = 15
TARGET_LEN = 16000 * TARGET_SECONDS
set_seed(SEED)

# ===== Load base model and source adapter =====
print("🔄 Loading source-finetuned model...")
source_ckpt = torch.load(SOURCE_MODEL_PATH, map_location=DEVICE)
cfg = BEATsConfig()
cfg.input_patch_size = (16, 16)
cfg.conv_bias = source_ckpt["cfg"].get("conv_bias", False)
cfg.frame_length = 384

model = BEATs(cfg)
model.load_state_dict(source_ckpt["model"], strict=False)
model.to(DEVICE).eval()

# ===== Merge source adapter =====
source_lora = LoraConfig(
    r=8, lora_alpha=16, lora_dropout=0.05,
    bias="none", task_type="FEATURE_EXTRACTION",
    target_modules=["q_proj", "v_proj"]
)
model = get_peft_model(model, source_lora)
model.load_state_dict(source_ckpt["model"], strict=False)
model.merge_and_unload()
print("✅ Source adapter merged into base model.")

# ===== Inject new LoRA adapter for PDA =====
target_lora = LoraConfig(
    r=8, lora_alpha=16, lora_dropout=0.05,
    bias="none", task_type="FEATURE_EXTRACTION",
    target_modules=["q_proj", "v_proj"]
)
model = get_peft_model(model, target_lora)
model.print_trainable_parameters()

# ===== Target Dataset =====
class TargetAudioDataset(Dataset):
    def __init__(self, base_dir):
        self.file_list = []
        for folder in os.listdir(base_dir):
            fpath = os.path.join(base_dir, folder)
            if os.path.isdir(fpath):
                self.file_list += [
                    os.path.join(fpath, f) for f in os.listdir(fpath) if f.endswith(".wav")
                ]
        print(f"🎧 Loaded {len(self.file_list)} target audio files.")

    def __len__(self): return len(self.file_list)

    def __getitem__(self, idx):
        path = self.file_list[idx]
        try:
            waveform, sr = torchaudio.load(path)
        except:
            return {"input_values": torch.zeros(TARGET_LEN)}  # fallback

        if waveform.shape[0] > 1:
            waveform = waveform.mean(dim=0, keepdim=True)

        if sr != 16000:
            waveform = torchaudio.transforms.Resample(orig_freq=sr, new_freq=16000)(waveform)

        waveform = torch.nn.functional.pad(waveform, (0, max(0, TARGET_LEN - waveform.shape[1])))
        waveform = waveform[:, :TARGET_LEN]
        return {"input_values": waveform.squeeze(0)}

dataset = TargetAudioDataset(TARGET_DIR)

# ===== Data Collator =====
def collate_fn(batch):
    processed = []
    for item in batch:
        if not isinstance(item, dict) or "input_values" not in item:
            processed.append(torch.zeros(TARGET_LEN))
        else:
            processed.append(item["input_values"])
    inputs = torch.stack(processed)
    return {"input_values": inputs}

# ===== Custom Trainer =====
class BEATsTrainer(Trainer):
    def compute_loss(self, model, inputs, return_outputs=False, **kwargs):
        x = inputs["input_values"].to(DEVICE)
        feat = model.extract_features(x)[0]  # [B, T, D]
        loss = torch.mean(feat ** 2)
        return (loss, feat) if return_outputs else loss

# ===== Training Args =====
training_args = TrainingArguments(
    output_dir="./pda-checkpoints",
    per_device_train_batch_size=BATCH_SIZE,
    num_train_epochs=NUM_EPOCHS,
    learning_rate=LEARNING_RATE,
    logging_steps=10,
    save_strategy="no",
    report_to="none",
    fp16=torch.cuda.is_available(),
    gradient_accumulation_steps=4
)

# ===== Train =====
trainer = BEATsTrainer(
    model=model,
    args=training_args,
    train_dataset=dataset,
    data_collator=collate_fn
)

print("🚀 Fine-tuning BEATs on target domain via PDA...")
trainer.train()
print("✅ PDA target fine-tuning complete.")

# ===== Save Final Model =====
print("💾 Merging target adapter into final model...")
model.merge_and_unload()
torch.save({"cfg": source_ckpt["cfg"], "model": model.state_dict()}, OUTPUT_MODEL_PATH)
print(f"✅ Final PDA model saved to: {OUTPUT_MODEL_PATH}")
# Out:
# 🔄 Loading source-finetuned model...
# No label_names provided for model class `PeftModelForFeatureExtraction`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
# ✅ Source adapter merged into base model.
# trainable params: 294,912 || all params: 90,596,480 || trainable%: 0.3255
# 🎧 Loaded 70 target audio files.
# 🚀 Fine-tuning BEATs on target domain via PDA...
#     <div>
#
#       <progress value='40' max='40' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [40/40 05:16, Epoch 4/5]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>10</td>
#       <td>0.067800</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.067800</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.067900</td>
#     </tr>
#     <tr>
#       <td>40</td>
#       <td>0.067700</td>
#     </tr>
#   </tbody>
# </table><p>
# ✅ PDA target fine-tuning complete.
# 💾 Merging target adapter into final model...
# ✅ Final PDA model saved to: K:/DCASE/BEATs_finetuned_target.pt

# %%
import os
import torch
import torchaudio
import numpy as np
from BEATs import BEATs, BEATsConfig

# ==== CONFIGURATION ====
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
CHECKPOINT_PATH = "K:/DCASE/BEATs_finetuned_target.pt"
BASE_INPUT_DIR = "K:/DCASE/Trainingdata"
BASE_OUTPUT_DIR = "C:/DCASE_Temp/FineTuned"
MASK_PARAM = 80  # SpecAugment mask width

# ==== LOAD CHECKPOINT ====
print("🔄 Loading checkpoint...")
checkpoint = torch.load(CHECKPOINT_PATH, map_location=DEVICE)
cfg = BEATsConfig()
cfg.input_patch_size = (16, 16)
cfg.conv_bias = checkpoint["cfg"].get("conv_bias", False)

print("🚀 Initializing BEATs model...")
model = BEATs(cfg)
model.load_state_dict(checkpoint["model"], strict=False)
model.to(DEVICE)
model.eval()
print("✅ BEATs model loaded successfully!")

# ==== SPEC-AUGMENT FUNCTION ====
def apply_specaugment(tensor, mask_param=80):
    tensor = tensor.unsqueeze(0)  # [1, Time, Feature]
    tensor = torchaudio.transforms.FrequencyMasking(freq_mask_param=mask_param)(tensor)
    tensor = torchaudio.transforms.TimeMasking(time_mask_param=mask_param)(tensor)
    return tensor.squeeze(0)  # [Time, Feature]

# ==== EMBEDDING EXTRACTION ====
def extract_beats_embedding(wav_file):
    try:
        waveform, sample_rate = torchaudio.load(wav_file)
        print(f"🔹 Loaded {wav_file}: Shape {waveform.shape}, Sample Rate {sample_rate}")
    except Exception as e:
        print(f"❌ Error loading {wav_file}: {e}")
        return None

    if waveform.shape[0] > 1:
        waveform = waveform.mean(dim=0, keepdim=True)

    if sample_rate != 16000:
        resampler = torchaudio.transforms.Resample(orig_freq=sample_rate, new_freq=16000)
        waveform = resampler(waveform)

    waveform = waveform.to(DEVICE)
    target_length = 16000 * 30
    waveform = torch.nn.functional.pad(waveform, (0, max(0, target_length - waveform.shape[1])))
    waveform = waveform[:, :target_length]

    print(f"🎵 Prepared waveform shape: {waveform.shape}")

    with torch.no_grad():
        try:
            features = model.extract_features(waveform)[0]  # [1, T, 768]
            print(f"🎛 Raw BEATs feature shape: {features.shape}")
            features = apply_specaugment(features.squeeze(0))  # [T, 768]
            return features.cpu().numpy()
        except Exception as e:
            print(f"❌ BEATs model error: {e}")
            return None

# ==== PROCESS FILES ====
def process_all_wav_files(base_input_dir, base_output_dir):
    os.makedirs(base_output_dir, exist_ok=True)

    for machine in os.listdir(base_input_dir):
        machine_input_dir = os.path.join(base_input_dir, machine)
        machine_output_dir = os.path.join(base_output_dir, machine)
        os.makedirs(machine_output_dir, exist_ok=True)

        for file in os.listdir(machine_input_dir):
            if not file.endswith(".wav"):
                continue

            input_path = os.path.join(machine_input_dir, file)
            output_path = os.path.join(machine_output_dir, f"BEATs_aug_{file.replace('.wav', '.npy')}")

            if os.path.exists(output_path):
                print(f"⏭️ Skipping {file} - already processed")
                continue

            embedding = extract_beats_embedding(input_path)
            if embedding is not None:
                print(f"💡 Embedding shape: {embedding.shape}")
                np.save(output_path, embedding)
                print(f"💾 Saved embedding to {output_path}")
            else:
                print(f"⚠️ Skipping {file} due to error.")

# ==== RUN ====
if __name__ == "__main__":
    process_all_wav_files(BASE_INPUT_DIR, BASE_OUTPUT_DIR)
    print("✅ All embeddings extracted with SpecAugment!")
# Out:
# 🔄 Loading checkpoint...
# 🚀 Initializing BEATs model...
# ✅ BEATs model loaded successfully!
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0001_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0001_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0002_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0002_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0003_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0003_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0004_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0004_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0005_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0005_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0006_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0006_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0007_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0007_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0008_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0008_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0009_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0009_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0010_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0010_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0011_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0011_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0012_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0012_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0013_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0013_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0014_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0014_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0015_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0015_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0016_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0016_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0017_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0017_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0018_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0018_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0019_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0019_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0020_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0020_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0021_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0021_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0022_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0022_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0023_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0023_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0024_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0024_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0025_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0025_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0026_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0026_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0027_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0027_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0028_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0028_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0029_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0029_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0030_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0030_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0031_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0031_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0032_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0032_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0033_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0033_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0034_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0034_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0035_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0035_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0036_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0036_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0037_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0037_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0038_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0038_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0039_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0039_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0040_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0040_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0041_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0041_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0042_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0042_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0043_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0043_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0044_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0044_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0045_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0045_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0046_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0046_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0047_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0047_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0048_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0048_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0049_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0049_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0050_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0050_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0051_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0051_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0052_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0052_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0053_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0053_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0054_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0054_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0055_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0055_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0056_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0056_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0057_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0057_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0058_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0058_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0059_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0059_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0060_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0060_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0061_pro_A_vel_4_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0061_pro_A_vel_4_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0062_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0062_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0063_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0063_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0064_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0064_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0065_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0065_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0066_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0066_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0067_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0067_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0068_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0068_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0069_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0069_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0070_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0070_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0071_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0071_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0072_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0072_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0073_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0073_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0074_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0074_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0075_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0075_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0076_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0076_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0077_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0077_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0078_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0078_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0079_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0079_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0080_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0080_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0081_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0081_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0082_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0082_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0083_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0083_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0084_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0084_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0085_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0085_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0086_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0086_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0087_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0087_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0088_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0088_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0089_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0089_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0090_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0090_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0091_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0091_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0092_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0092_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0093_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0093_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0094_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0094_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0095_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0095_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0096_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0096_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0097_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0097_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0098_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0098_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0099_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0099_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0100_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0100_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0101_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0101_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0102_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0102_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0103_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0103_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0104_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0104_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0105_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0105_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0106_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0106_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0107_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0107_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0108_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0108_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0109_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0109_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0110_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0110_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0111_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0111_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0112_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0112_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0113_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0113_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0114_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_bearing\BEATs_aug_section_00_source_train_normal_0114_pro_A_vel_12_loc_A.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_bearing\section_00_source_train_normal_0115_pro_A_vel_12_loc_A.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# ...
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0962_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0963_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0963_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0964_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0964_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0965_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0965_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0966_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0966_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0967_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0967_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0968_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0968_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0969_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0969_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0970_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0970_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0971_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0971_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0972_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0972_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0973_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0973_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0974_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0974_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0975_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0975_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0976_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0976_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0977_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0977_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0978_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0978_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0979_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0979_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0980_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0980_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0981_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0981_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0982_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0982_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0983_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0983_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0984_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0984_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0985_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0985_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0986_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0986_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0987_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0987_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0988_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0988_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0989_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0989_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_source_train_normal_0990_v1pat_B_v2pat_none.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_source_train_normal_0990_v1pat_B_v2pat_none.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0001_v1pat_A_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0001_v1pat_A_v2pat_B.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0002_v1pat_A_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0002_v1pat_A_v2pat_B.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0003_v1pat_A_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0003_v1pat_A_v2pat_B.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0004_v1pat_B_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0004_v1pat_B_v2pat_B.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0005_v1pat_B_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0005_v1pat_B_v2pat_B.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0006_v1pat_B_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0006_v1pat_B_v2pat_B.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0007_v1pat_B_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0007_v1pat_B_v2pat_B.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0008_v1pat_B_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0008_v1pat_B_v2pat_B.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0009_v1pat_A_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0009_v1pat_A_v2pat_B.npy
# 🔹 Loaded K:/DCASE/Trainingdata\train_valve\section_00_target_train_normal_0010_v1pat_A_v2pat_B.wav: Shape torch.Size([1, 160000]), Sample Rate 16000
# 🎵 Prepared waveform shape: torch.Size([1, 480000])
# 🎛 Raw BEATs feature shape: torch.Size([1, 1496, 768])
# 💡 Embedding shape: (1496, 768)
# 💾 Saved embedding to C:/DCASE_Temp/FineTuned\train_valve\BEATs_aug_section_00_target_train_normal_0010_v1pat_A_v2pat_B.npy
# ✅ All embeddings extracted with SpecAugment!
